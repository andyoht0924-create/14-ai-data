# %%
# Do not reinvert the wheel
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Jason Mills'

# %%
fake.address()
# Out:
# '04305 Vincent Pike\nPort Kristaport, UT 50259'

# %%
test_data = [(fake.name(), fake.address()) for _ in range(30)]
print(test_data)
# Out:
# [('Mr. Timothy Mcdaniel MD', '3725 Misty Via\nVasquezfort, MS 13960'), ('Richard Bowen', 'Unit 3079 Box 3454\nDPO AA 11018'), ('James Tyler', '74555 Ryan Fall Apt. 941\nNorth Melissa, MD 73556'), ('Douglas Dyer', 'Unit 5316 Box 6542\nDPO AA 89428'), ('Katherine Harris', '3422 Sexton Loaf Suite 124\nNorth Anthony, ME 65865'), ('Kenneth Bennett', '41833 King Tunnel Apt. 224\nMaryville, ME 91272'), ('Frank Wheeler', '5249 Hill View\nPeterside, HI 40987'), ('Steven Henry', '255 Woodward Course\nDuranborough, MH 61738'), ('Marilyn Huang', '695 Heidi Shores\nSouth Richard, NH 04419'), ('Billy Rosales', '8419 Jasmine Freeway Suite 162\nLindaside, IL 89311'), ('Vanessa Sanders', '4444 Mora Parkways\nSouth Carol, MP 72983'), ('Andrew Stephens', '250 Fitzgerald Loop Suite 232\nEast Matthew, DE 49925'), ('Daniel Stewart', 'Unit 2075 Box 9268\nDPO AP 96304'), ('Victoria Reyes', '413 Smith Bridge\nAshleybury, KS 43808'), ('Robin Humphrey', '60867 Hernandez Mill\nWest Donnamouth, CT 74257'), ('All
# ...
